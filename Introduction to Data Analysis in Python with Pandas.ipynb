# %% [markdown]
# # Introduction to Data Analysis in Python with Pandas
# This notebook covers the three-hour workshop designed and taught by [Chreston Miller](mailto:chmille3@vt.edu) and [Nathaniel Porter](mailto:ndporter@vt.edu), Virginia Tech University Libraries.
#
# Some material adapted from [Software Carpentry](https://software-carpentry.org/) and [Data Carpentry](https://datacarpentry.org/) lessons.
#
# All content, both original and remixed, is licensed under Creative Commons Attribution 4.0 International ([CC-BY](https://creativecommons.org/licenses/by/4.0/legalcode)) license and can be freely reused and adapted, as long as credit is provided to the original source.
#
# See repository for date of last update.

# %% [markdown]
# **This workshop is designed to introduce someone with low to moderate coding experience to data analysis in Python 3. It assumes no Python background and no statistics or data analytics background. We recommend downloading the free [Anaconda](https://www.anaconda.com/distribution/) package for best experience, but you can use any distribution of Python 3, as long as you also have Jupyter notebooks installed.**
#
# All packages here are standard in Anaconda. If not using Anaconda, you may need to download additional packages.

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Start by opening the Anaconda Navigator. It provides an overview of some of the tools you can use to work with Python. For now, we'll use Jupyter notebooks, an interactive notebook that allows you to type and run code and see the results inline. Click "Launch" on the "Notebook" divider.
#
# You should see the items in your user directory, within a Jupyter skin in your default browser. For now, click "New-Python 3" in the top right corner.
#
# You've just made a notebook. The first thing you should do is give it a name by clicking the word "Untitled" at the top of the screen. Make sure names are descriptive and clear, such as "2019-02-21 Python and Pandas Workshop."
#
# You'll be able to practice your Python skills in this notebook as we go, and save it for future reference.
#
# All you should see in the body for now is a highlighted box with "In \[ \]:". That box is called a "Cell" in Jupyter notebooks and can be used for text or code.
#
# To make a text only box, select the dropdown that says "Code" at the top of the page and change it to "Markdown." Markdown is a way to write text using a few basic codes to guide display. This cell is written in Markdown, so if I surround text in \*s, it will be *italic* or if I use two \*s, it will be **bold**. To learn more about Markdown, select "Markdown" from the Jupyter help menu.

# %%
#Sometimes you want to mix text with code...
#particularly if you want to document what you're doing and why.
#If you type a # in a line of Python code...
#it will treat everything after the # as a comment and ignore when running code.

#Try it now by pressing typing a comment in the cell then pressing ALT-ENTER.
#This will run a code block and insert a new block below.

# %%
#Because everything in the block was a comment, nothing ran.
Type something in the new block without a comment, then press ALT-ENTER.
# Out:
#   File "<ipython-input-3-51232035b06b>", line 2
#     Type something in the new block without a comment, then press ALT-ENTER.
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Congratulations**, you threw your first error! The line above wasn't Python code, so when Jupyter sent the code to Python, it didn't know what to do with it. Notice that errors tell you *what went wrong* ("SyntaxError: invalid syntax") and *where* (the carrot pointing to the second word). We'll see more errors later.

# %% [markdown]
# ## Foundational Python
#
# This section of the workshop introduces you to fundamental data types and procedures in base Python, e.g. Python without any add-on packages. This is not a comprehensive introduction, but focused on things you might want to know for data analysis tasks. Python is a flexible and complete programming language that is used for everything from data analysis and user interfaces to game development.
#
# Let's start by finding out a little about what Python can do and how it stores data. Follow along by trying out the procedures as they're being demonstrated. Make sure to add comments to your code blocks so you can remember why they were important.

# %%
#Python can be used as a calculator
9 + 6
# Out:
# 15

# %%
#Notice the output is labeled "Out" when you run a cell without error

#If you don't want to insert a new cell, use SHIFT-ENTER to run a cell
#You can also insert cells with the "Insert" menu and delete from the "Edit" menu
4* 234
# Out:
# 936

# %%
#variables are data associated with a name
#here the variable name is 'weight_kg' and the value is 60
weight_kg = 60

# %%
#variables can also reference strings
#qoutes (single or double) tell Python it's a string, not a name
weight_kg_text = weight in kilograms
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-82f26f717b6e> in <module>
#       1 #variables can also reference strings
#       2 #qoutes (single or double) tell Python it's a string, not a name
# ----> 3 weight_kg_text = weight in kilograms
#
# NameError: name 'weight' is not defined

# %%
#oops - notice the error tells us what happened
#Python assumed weight (no quotes) was a variable name and didn't find it

#let's try it with quotes
weight_kg_text = "weight in kilograms"

# %%
#print displays values and/or strings
print(weight_kg)
# Out:
# 60

# %%
#combine two variables in one print (the comma makes a space)
print(weight_kg_text, weight_kg)
# Out:
# weight in kilograms 60

# %%
#strings can also be referenced directly, without assigning a variable

#numeric variables can be used in mathematical expressions
print('weight in pounds:',2.2 * weight_kg)
# Out:
# weight in pounds: 132.0

# %%
#mathematical operations don't change the underlying variable...
print(weight_kg)
# Out:
# 60

# %%
#but variables can be reassigned (to a new value)
weight_kg = 65.0
print('weight in kilograms is now:', weight_kg)
# Out:
# weight in kilograms is now: 65.0

# %%
#define a function to perform the same operation repeatedly
#Python uses indentation to tell what's within a function
#the parentheses allow you to pass information to the function that affects what it does
def kg_to_pounds(kg_w):
    print('weight in kilograms:', kg_w)
    print('weight in pounds:', 2.2*kg_w)
    
#every indented line after the def: statement is run when the function is called
#you can use variable or values as input to a function

#to call the function, just use it in a line of code
#here we print the weight of our variable in both kg and pounds
kg_to_pounds(weight_kg)
# Out:
# weight in kilograms: 65.0
# weight in pounds: 143.0

# %%
#you can run the function as many times as you want on different values
#an adult male gunea pig weighs around 1.1 kg - how much in pounds?
kg_to_pounds(1.1)
# Out:
# weight in kilograms: 1.1
# weight in pounds: 2.4200000000000004

# %%
#Let's work more with strings
word = 'lead'

# %%
#a string is stored as a vector of characters
#square brackets are used in Python to reference a position
#"0" is the first position in python, so this call will print the 4th letter
print(word[3])
# Out:
# d

# %%
print(word[4])
#oops - we got an error because there is no word[4]
#it only has 4 letters
#use the error type and text to figure out what went wrong
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-047580cc4e88> in <module>
# ----> 1 print(word[4])
#       2 #oops - we got an error because there is no word[4]
#       3 #it only has 4 letters
#       4 #use the error type and text to figure out what went wrong
#
# IndexError: string index out of range

# %%
#for loops allow you to do the same action with each part of a vector
for char in word:
    print(char)
# Out:
# l
# e
# a
# d

# %%
#Python uses indentation to scope loops (like defined functions)
#anything indented under a loop will run once for each item
for char in word:
    print(char)
    print("Hello World")
# Out:
# l
# Hello World
# e
# Hello World
# a
# Hello World
# d
# Hello World

# %%
#watch what happens if we move it outside the loop
for char in word:
    print(char)
print("Hello World")
# Out:
# l
# e
# a
# d
# Hello World

# %%
#python doesn't care if what we call something makes sense
#but it will help you later if it does
for banana in word:
    print(banana)
# Out:
# l
# e
# a
# d

# %%
length = 0
#you can interact with a variable's value using expressions
for vowel in 'aeiou':
    length = length + 1
print('There are',length,'vowels')
# Out:
# There are 5 vowels

# %%
length=99
def get_length(string):
    length = 0
    for vowel in string:
        length += 1
    print('there are',length,'vowels')

print('length before:',length)
get_length('aeiou')
print('length after:',length)
# Out:
# length before: 99
# there are 5 vowels
# length after: 99

# %%
#use brackets and commas to make a list (or vector) of values
odds = [1,3,5,7]
print('odds are:',odds)
# Out:
# odds are: [1, 3, 5, 7]

# %%
#you can access positions in a list
#0 is first, 1 is second, etc
#Negative positions count backward from the end
print('first and last:',odds[0],odds[-1])
# Out:
# first and last: 1 7

# %%
for number in odds:
    print(number)
# Out:
# 1
# 3
# 5
# 7

# %%
#you can change a single value in a list, as well
odds[0] = 4

# %%
print(odds)
# Out:
# [4, 3, 5, 7]

# %%
print(word)
# Out:
# lead

# %%
#but even though you can access string positions, they're not lists
word[0] = 'L'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-9d6ae945fcaf> in <module>
#       1 #but even though you can access string positions, they're not lists
# ----> 2 word[0] = 'L'
#
# TypeError: 'str' object does not support item assignment

# %%
word = 'Lead'

# %%
print(word)
# Out:
# Lead

# %%
#lets put 1 back in the odds list
print(odds)
# Out:
# [4, 3, 5, 7]

# %%
odds[0] = 1

# %%
print(odds)
# Out:
# [1, 3, 5, 7]

# %%
#add to the end of a list with append
odds.append(11)
print('odds after adding a value:',odds)
# Out:
# odds after adding a value: [1, 3, 5, 7, 11]

# %%
#remove the item in a specific position with del
del odds[-1]
print('odds after removing the last element:',odds)
# Out:
# odds after removing the last element: [1, 3, 5, 7]

# %%
#reverse changes the order (so position -1 becomes 0, -2 becomes 1 etc). 
#this is done 'in place' meaning it immediately changes the variable
#contrast this to our converting kg to pounds, which left the variable in kg
odds.reverse()
print('odds after reversing:',odds)
# Out:
# odds after reversing: [7, 5, 3, 1]

# %%
#let's make an out of order list of numbers
numbers = [2,7,9,3,1,4,23,7]
#now use sort to put them in order (low to high)
numbers.sort()
print("numbers after sorting:",numbers)
# Out:
# numbers after sorting: [1, 2, 3, 4, 7, 7, 9, 23]

# %%
#when you assign two variables as equal, they reference each other, not copy
odds = [1,3,5,7]
primes = odds
primes.append(2)
print('primes:',primes)
print('odds',odds)
print('changing primes accidentally changed odds')
# Out:
# primes: [1, 3, 5, 7, 2]
# odds [1, 3, 5, 7, 2]
# changing primes accidentally changed odds

# %%
odds = [1,3,5,7]
#using list(odds) makes a copy instead of a reference
primes = list(odds)
primes.append(2)
print('primes:',primes)
print('odds',odds)
print('Success! We did not add 2 to odds this time')
# Out:
# primes: [1, 3, 5, 7, 2]
# odds [1, 3, 5, 7]
# Success! We did not add 2 to odds this time

# %%
#get a slice (portion) of a list or vector using [] and :
#Get the first 3 odd numbers
odds[0:3]
# Out:
# [1, 3, 5]

# %%
#Another example - not starting from the beginning
odds[2:4]
# Out:
# [5, 7]

# %%
#notice that slices include the first endpoint but not the second
#you can verify this
odds[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-74fefef333aa> in <module>
#       1 #notice that slices include the first endpoint but not the second
#       2 #you can verify this
# ----> 3 odds[4]
#
# IndexError: list index out of range

# %%
#Another example of negative indexing
odds[-1]
# Out:
# 7

# %%
#if expressions allow us to do other actions based on variable value 
num = 37
#the format is "if VAR TEST VALUE:"
if num > 100:
    print('greater')
#use else to tell Python what to do if an expression is false 
else:
    print('not greater')
print('done!')
# Out:
# not greater
# done!

# %%
num = 53
print("before conditional...")
#else isn't required; just nothing happens if the expression is false
if num > 100:
    print (num,'is greater than 100')
print('...after conditional')
# Out:
# before conditional...
# ...after conditional

# %%
num = -3
#elif (else if) allows testing multiple possibilities in the same if-statement
#if the first if is true, the elif and else are ignored
#if the first if is false, the elif is tested next
#else only runs if everything above is false, kind of a "catch all"

#define a function that checks whether a number is positive, negative, or zero
def pos_neg_z(n):
    if n > 0:
        print(n,'is positive')
    elif n == 0:
        print(n,'is zero')
    else:
        print(n,'is negative')

#run the function on our number
pos_neg_z(num)

#if you get an error, check two things:

#1. Check that the indenting is consistent
#def should be unindented
#if/elif/else should be indented one level
#the prints should be indented two levels

#2. Check that you have colons at the end of def, if, elif, and else statements
# Out:
# -3 is negative

# %%
#you can use and to test if two things are both true
if (1>0) and (-1 > 0):
    print('both parts are true')
else:
    print('at least one part is false')
# Out:
# at least one part is false

# %%
#use or to test if at least one is true
if (1 < 0) or (-1 < 0):
    print('at least one test is true')
# Out:
# at least one test is true

# %% [markdown]
# ## Working with Dataframes in Pandas
#
# Python is highly extensible through a system of add-on packages. This allows more flexibility for developers and saves system resources by not loading everything you might possibly use. Anaconda includes many of the most popular packages, including pandas (Python ANalysis of DAta), which allows for easily loading and working with data through the DataFrame structure.
#
# A dataframe can be compared to a table, a "flat" data file like a csv, or a single spreadsheet from a workbook program like Excel. More often than not, it can also be created directly from those or other file types, including data saved in popular statistics packages like R, Stata, SAS, and SPSS.
#
# This section of the workshop introduces the idea of dataframes and demonstrates how you might familiarize yourself with your data and look for and address possible problems.

# %%
#packages add functionality to Python
#import them with "import"
#it's common to use abbreviations for certain packages with the "as" option
import pandas as pd

# %%
#a csv file is a plain text data file
#columns are separated by commas
#each row is a single case

#you can import a csv file with the read_csv method in pandas
indata = pd.read_csv('http://bit.ly/msd_top_artists')

#when you import data, you can quickly check its contents with head
#head() displays the first few cases
indata.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1             song_id           artist_id  \
# 0          71            71  SOVJXVJ12A8C13517D  ARCCRTI11F4C845308
# 1          76            76  SOWHYUG12A58A77FAB  ARODBRG1187FB3FD99
# 2         270           270  SOTVEKK12A8C1392E1  ARX9YIP1187B98A656
# 3         344           344  SOUPIRU12A6D4FA1E1  ARJIE2Y1187B994AB7
# 4         406           406  SOGXQRO12A8AE47D50  ARN03F71187FB4E3F4
#
#                  artist_name  artist_familiarity  artist_hotttnesss  \
# 0                White Heart            0.477365           0.337507
# 1  Nick Cave & The Bad Seeds            0.694022           0.479408
# 2                    RUN-DMC            0.686989           0.606630
# 3                Line Renaud            0.470212           0.320087
# 4                        Ayo            0.522590           0.390641
#
#                                                title  song_hotttnesss  year  \
# 0  Where The Thunder Roars (Tales Of Wonder Album...         0.265861     0
# 1              She Fell Away (2009 Digital Remaster)              NaN     0
# 2                                         Hard Times              NaN  1984
# 3                                Der Kleine Dompfaff              NaN     0
# 4                                           Complain         0.000000  2006
#
#     duration  loudness    tempo    artist_mbtags  \
# 0  298.84036    -9.998  113.277             none
# 1  269.26975   -11.751  144.603        seen live
# 2  234.65751   -12.750  119.670          hip-hop
# 3  152.92036    -9.843  124.750             none
# 4  212.71465   -11.260  128.689  soul and reggae
#
#                                             release  release_7digitalid
# 0                                   Tales Of Wonder              148547
# 1  Your Funeral... My Trial (2009 Digital Remaster)              413222
# 2                                           Run DMC              293884
# 3                              Platinum Line Renaud              272703
# 4                                            Joyful              350343

# %% [markdown]
# Rows in this dataset are songs from the Million Song Data project. The data only include artists with at least 10 songs in the master database. This allows comparing artists based on song characteristics.
#
# Look at the columns and notice the following...
#
# String variables:
# - song_id
# - artist_id
# - artist_name
# - title
# - artist_mbtags
# - release
#
# Numeric variables:
# - artist_familiarity
# - artist_hotttnesss
# - song_hotttnesss
# - year
# - duration
# - loudness
# - tempo
#
# ????? variables:
# - Unnamed: 0 (extra id column; unnecessary)
# - Unnamed: 0.1 (extra id column; unnecessary)
# - release_7digitalid
#
# You can find more of any of the variables in the [codebook](http://bit.ly/2IsAS4F). Investigate *release_7digitalid*.

# %%
#release_7digitalid looks numeric but it's just an id number
#be careful to treat variables like this as strings in analysis

#you can use describe to provide summaries of each numeric varaible
#min and max help understand how variables are defined
#mean and std (standard deviation) provide basic information on the distribution
#percentiles give more detailed information on specific parts of distribution
#count is useful to check for missing data
indata.describe()
#notice ???? variables are included because Python assumed they're numbers
# Out:
#         Unnamed: 0  Unnamed: 0.1  artist_familiarity  artist_hotttnesss  \
# count   237.000000    237.000000          237.000000         237.000000
# mean   4811.362869   4811.362869            0.622757           0.451895
# std    2804.775116   2804.775116            0.192123           0.191229
# min      71.000000     71.000000            0.313851           0.049034
# 25%    2498.000000   2498.000000            0.470212           0.333303
# 50%    4464.000000   4464.000000            0.608704           0.390641
# 75%    7414.000000   7414.000000            0.818319           0.606630
# max    9992.000000   9992.000000            0.899935           0.808502
#
#        song_hotttnesss         year    duration    loudness       tempo  \
# count       113.000000   237.000000  237.000000  237.000000  237.000000
# mean          0.407803  1001.455696  231.513663  -10.293586  122.211046
# std           0.263034   999.374353   81.125318    4.305802   35.114772
# min           0.000000     0.000000   29.491790  -29.521000   40.270000
# 25%           0.261733     0.000000  185.991380  -12.370000   99.680000
# 50%           0.445455  1972.000000  223.215870   -9.932000  117.537000
# 75%           0.607037  1995.000000  273.867300   -7.037000  143.431000
# max           0.945995  2009.000000  551.914650   -1.479000  241.242000
#
#        release_7digitalid
# count          237.000000
# mean        312785.092827
# std         229226.537869
# min            450.000000
# 25%         121392.000000
# 50%         287752.000000
# 75%         420159.000000
# max         776439.000000

# %%
#song_hotttnesss is only valid for 113 songs

#remove missing data with dropna (but make sure to keep a copy of the unaltered data)
#the subset parameter lists variables to check for missing values
artist_data = indata.dropna(subset=['song_hotttnesss'])
artist_data.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  artist_familiarity  artist_hotttnesss  \
# count   113.000000    113.000000          113.000000         113.000000
# mean   4700.212389   4700.212389            0.658759           0.483748
# std    2747.411991   2747.411991            0.154490           0.144884
# min      71.000000     71.000000            0.323009           0.049034
# 25%    2351.000000   2351.000000            0.522590           0.360446
# 50%    4134.000000   4134.000000            0.655921           0.479408
# 75%    7512.000000   7512.000000            0.818319           0.604667
# max    9805.000000   9805.000000            0.899935           0.808502
#
#        song_hotttnesss         year    duration    loudness       tempo  \
# count       113.000000   113.000000  113.000000  113.000000  113.000000
# mean          0.407803  1147.743363  228.586463  -10.292265  121.967956
# std           0.263034   990.715504   62.029246    3.747008   33.685595
# min           0.000000     0.000000   44.198730  -21.343000   40.270000
# 25%           0.261733     0.000000  185.991380  -12.274000   99.948000
# 50%           0.445455  1984.000000  217.573420  -10.319000  117.362000
# 75%           0.607037  1996.000000  269.348120   -7.659000  143.431000
# max           0.945995  2009.000000  388.518730   -2.267000  208.567000
#
#        release_7digitalid
# count          113.000000
# mean        270518.141593
# std         243825.201138
# min            738.000000
# 25%          40837.000000
# 50%         225997.000000
# 75%         405065.000000
# max         776437.000000

# %%
#now all the variables have 113 valid cases
#let's look at all the cases instead of just the first few
artist_data
# Out:
#      Unnamed: 0  Unnamed: 0.1             song_id           artist_id  \
# 0            71            71  SOVJXVJ12A8C13517D  ARCCRTI11F4C845308
# 4           406           406  SOGXQRO12A8AE47D50  ARN03F71187FB4E3F4
# 5           469           469  SOVIRCP12AB01891FE  AROF4LP1187FB41C51
# 6           507           507  SOSMXVH12A58A7CA6C  AR6PJ8R1187FB5AD70
# 7           513           513  SOQSYGY12A8C137E0F  AROF4LP1187FB41C51
# 9           660           660  SOSYMSX12A6310DFE2  ARH6W4X1187B99274F
# 10          675           675  SOWJNKL12A81C21F17  ARODBRG1187FB3FD99
# 15          860           860  SOGWNKK12A6701D95A  ARVN9FZ1187FB393F1
# 16          866           866  SORUWYJ12AB0181EBF  ART3O5Z1187B9AB043
# 18          997           997  SOQUGOE12A6D4FA6FF  ARKC83D1187B9AB367
# 19         1010          1010  SOBANAT12A6D4F7501  ARE8GLF1187FB52532
# 21         1041          1041  SOCHRGA12AB017D5CE  ARIRD6J1187FB5A98C
# 30         1317          1317  SOCXRVU12A6D4F87A2  ARIRD6J1187FB5A98C
# 31         1319          1319  SOYKSBN12AB017EF6B  ART3O5Z1187B9AB043
# 32         1328          1328  SOGVJTG12A6701E991  AR12F2S1187FB56EEF
# 33         1358          1358  SOFNTFC12AB0184512  ARBB58Y1187B9B621B
# 34         1444          1444  SOFMMKA12A58A7CBF5  AR9W3X91187FB3994C
# 35         1468          1468  SOBUAFP12A6D4F9934  AROIHOI122988FEB8E
# 38         1508          1508  SOBPYWO12A8C133A1A  ARBB58Y1187B9B621B
# 40         1853          1853  SORXWXC12A6D4F87B3  ARJIE2Y1187B994AB7
# 43         2022          2022  SODEXMV12A8C13B960  ARX9YIP1187B98A656
# 44         2073          2073  SOKFQQD12A8C138826  ARBB58Y1187B9B621B
# 46         2206          2206  SORURGG12A8C13E8BF  ARX9YIP1187B98A656
# 47         2207          2207  SORUIOA12A8C13F7CE  ARDW74M1187B98DA34
# 48         2222          2222  SOSRGHC12AB01869E0  AR7KA5V1187FB44E6B
# 49         2263          2263  SOQOQNQ12A81C21F1B  ARODBRG1187FB3FD99
# 50         2311          2311  SOCUDML12A5829113A  AREWQSE1187B9AEC6C
# 51         2312          2312  SOEERUL12A8C144976  AR7KA5V1187FB44E6B
# 53         2351          2351  SOAZIRE12A6702046F  ARE8GLF1187FB52532
# 56         2424          2424  SOENTVS12A8C136556  ARIRD6J1187FB5A98C
# ..          ...           ...                 ...                 ...
# 170        7185          7185  SOOEXUJ12A6701E77F  ARODBRG1187FB3FD99
# 181        7512          7512  SONSQLD12A6310D960  ARODBRG1187FB3FD99
# 182        7566          7566  SOMLGKF12AB017DF3C  ARH6W4X1187B99274F
# 183        7598          7598  SOHKTJX12AB0185A8D  ARIRD6J1187FB5A98C
# 184        7614          7614  SOTOMJM12A8C134AA2  AR12F2S1187FB56EEF
# 186        7747          7747  SODQZAW12AB0184A51  ARH6W4X1187B99274F
# 187        7764          7764  SOMMJVR12A6D4F98E0  ARE8GLF1187FB52532
# 188        7803          7803  SODMJWA12A8C13BA03  ARX9YIP1187B98A656
# 189        7811          7811  SOZNZIN12A6701E95F  AR12F2S1187FB56EEF
# 193        7931          7931  SODZSJG12A6D4F87AF  ARJIE2Y1187B994AB7
# 194        7964          7964  SOKIZGL12AB018342D  ARH6W4X1187B99274F
# 195        8070          8070  SOMDWZC12A8C13A065  ARBB58Y1187B9B621B
# 196        8149          8149  SOBPTED12A6D4F99C7  AR9W3X91187FB3994C
# 197        8218          8218  SOBUPHJ12A58A7C7F8  ARBB58Y1187B9B621B
# 200        8325          8325  SODPYXE12A58A7AF97  AR78ZID1187B9B31ED
# 201        8329          8329  SOKGYMR12A8C1433E3  AR7KA5V1187FB44E6B
# 203        8374          8374  SOYBGAM12AB017A82A  ARCCRTI11F4C845308
# 204        8534          8534  SOTDEPN12AC3DF46DB  ARODBRG1187FB3FD99
# 206        8577          8577  SOYHHHT12A6D4F7F97  AR9W3X91187FB3994C
# 207        8590          8590  SOJPNCH12A67AE0E21  ARN03F71187FB4E3F4
# 210        8707          8707  SOGHXZH12A8C1388B9  ARXPPEY1187FB51DF4
# 211        8778          8778  SOMYGCE12A8C134338  ARCCRTI11F4C845308
# 212        8829          8829  SORXSAJ12A6D4F92BA  ARVN9FZ1187FB393F1
# 215        8920          8920  SOXAPVV12A67020F8C  ARODBRG1187FB3FD99
# 216        8993          8993  SOOYYUG12A8C1440CA  AR7KA5V1187FB44E6B
# 219        9133          9133  SOUMBKO12A8C135722  AR12F2S1187FB56EEF
# 227        9461          9461  SOCOZST12A67020452  ARE8GLF1187FB52532
# 228        9477          9477  SOXFQVY12A58A7B456  AR9W3X91187FB3994C
# 233        9801          9801  SOVBQWR12A8C137843  ARJIE2Y1187B994AB7
# 234        9805          9805  SOPKJJT12A8C1433B0  AR7KA5V1187FB44E6B
#
#                                artist_name  artist_familiarity  \
# 0                              White Heart            0.477365
# 4                                      Ayo            0.522590
# 5                                   Selena            0.748321
# 6                                  Shakira            0.833179
# 7                                   Selena            0.748321
# 9                                Radiohead            0.899935
# 10               Nick Cave & The Bad Seeds            0.694022
# 15                             Snow Patrol            0.818319
# 16   Stevie Ray Vaughan And Double Trouble            0.733799
# 18                   Bill & Gloria Gaither            0.493926
# 19                   Red Hot Chili Peppers            0.833968
# 21                            Sugar Minott            0.606976
# 30                            Sugar Minott            0.606976
# 31   Stevie Ray Vaughan And Double Trouble            0.733799
# 32                               Aerosmith            0.872537
# 33                   Bill & Gloria Gaither            0.426883
# 34                            Phil Collins            0.655921
# 35                        Mario Rosenstock            0.334543
# 38                   Bill & Gloria Gaither            0.426883
# 40                             Line Renaud            0.470212
# 43                                 RUN-DMC            0.686989
# 44                   Bill & Gloria Gaither            0.426883
# 46                                 RUN-DMC            0.686989
# 47                   Bill & Gloria Gaither            0.434026
# 48                    The Del McCoury Band            0.608704
# 49               Nick Cave & The Bad Seeds            0.694022
# 50               The Jackson Southernaires            0.323009
# 51                    The Del McCoury Band            0.608704
# 53                   Red Hot Chili Peppers            0.833968
# 56                            Sugar Minott            0.606976
# ..                                     ...                 ...
# 170              Nick Cave & The Bad Seeds            0.694022
# 181              Nick Cave & The Bad Seeds            0.681581
# 182                              Radiohead            0.899935
# 183                           Sugar Minott            0.606976
# 184                              Aerosmith            0.872537
# 186                              Radiohead            0.899935
# 187                  Red Hot Chili Peppers            0.833968
# 188                                RUN-DMC            0.686989
# 189                              Aerosmith            0.872537
# 193                            Line Renaud            0.470212
# 194                              Radiohead            0.899935
# 195                  Bill & Gloria Gaither            0.426883
# 196                           Phil Collins            0.655921
# 197                  Bill & Gloria Gaither            0.426883
# 200                            Mikey Dread            0.585683
# 201                   The Del McCoury Band            0.608704
# 203                            White Heart            0.477365
# 204              Nick Cave & The Bad Seeds            0.681581
# 206                           Phil Collins            0.655921
# 207                                    Ayo            0.522590
# 210                        Michael Jackson            0.866520
# 211                            White Heart            0.477365
# 212                            Snow Patrol            0.818319
# 215              Nick Cave & The Bad Seeds            0.681581
# 216                   The Del McCoury Band            0.608704
# 219                              Aerosmith            0.872537
# 227                  Red Hot Chili Peppers            0.833968
# 228                           Phil Collins            0.655921
# 233                            Line Renaud            0.470212
# 234                   The Del McCoury Band            0.608704
#
#      artist_hotttnesss                                              title  \
# 0             0.337507  Where The Thunder Roars (Tales Of Wonder Album...
# 4             0.390641                                           Complain
# 5             0.545866                       Ven Conmigo/Perdoname (Live)
# 6             0.804220                                       Pienso En Ti
# 7             0.545866            Como La Flor (2005 Re-mastering) (Live)
# 9             0.683658                        Subterranean Homesick Alien
# 10            0.479408                                      Still In Love
# 15            0.667295                                       Half The Fun
# 16            0.544258                                         Empty Arms
# 18            0.319627                                        Awesome God
# 19            0.576904                  Naked In The Rain (Album Version)
# 21            0.386290                                 All Kind of People
# 30            0.386290                                        Walking Dub
# 31            0.544258                                 Chitlins Con Carne
# 32            0.610731                                              Angel
# 33            0.333303                     He Will Lead His Children Home
# 34            0.578302                                            Welcome
# 35            0.049034                                              Smoke
# 38            0.333303             Holy Ground (Homecoming Hymns Version)
# 40            0.320087                                         Gwendolina
# 43            0.606630                                              Faces
# 44            0.333303  Jesus Hold My Hand (The Best of Homecoming - V...
# 46            0.606630                                              Crack
# 47            0.234520           Stand By Me (Freedom Band Album Version)
# 48            0.362219                                Rain Please Go Away
# 49            0.479408                                  Rock Of Gibraltar
# 50            0.311438                                     Thank You Mama
# 51            0.362219                             Gone But Not Forgotten
# 53            0.576202                       Venice Queen (Album Version)
# 56            0.386290                                           Informer
# ..                 ...                                                ...
# 170           0.479408                                           Loverman
# 181           0.479408                     Where Do We Go Now But Nowhere
# 182           0.683658                                   Vegetable (Live)
# 183           0.386290                                             A True
# 184           0.610731                                      Milkcow Blues
# 186           0.604667            You Never Wash Up After Yourself (Live)
# 187           0.576904                Hard To Concentrate (Album Version)
# 188           0.606630                                 Jam-Master Jammin'
# 189           0.610731                                  Janie's Got A Gun
# 193           0.320087                                        Mambo Bacan
# 194           0.604667                                         You (Demo)
# 195           0.333303  I'll Meet You By The River (Southern Conventio...
# 196           0.578302                        You Can't Hurry Love (Live)
# 197           0.333303                  I Walked Today Where Jesus Walked
# 200           0.360446                                           Problems
# 201           0.362219                    Don't You Think It's Time To Go
# 203           0.337507  Speed Of Sound (Emergency Broadcast Album Vers...
# 204           0.479408  Christina The Astonishing (2010 Digital Remaster)
# 206           0.578302                                     One More Night
# 207           0.390641                                       Watching You
# 210           0.766545                                    Heaven Can Wait
# 211           0.337507           Change The Way (Highlands Album Version)
# 212           0.667295                It Doesn't Matter Where_ Just Drive
# 215           0.479408                                 New Morning (Live)
# 216           0.362219                               High On the Mountain
# 219           0.611118                                  Reefer Head Woman
# 227           0.576904                  Parallel Universe (Album Version)
# 228           0.578302                                           Everyday
# 233           0.320087                         Il N'Etait Pas Sentimental
# 234           0.362219               It's Surprising What the Lord Can Do
#
#      song_hotttnesss  year   duration  loudness    tempo  \
# 0           0.265861     0  298.84036    -9.998  113.277
# 4           0.000000  2006  212.71465   -11.260  128.689
# 5           0.000000     0  388.51873    -5.680  106.438
# 6           0.701124  1995  148.19220   -19.976  115.066
# 7           0.000000     0  329.58649    -7.951  182.168
# 9           0.775024  1997  267.20608    -9.148  150.848
# 10          0.591758  2003  283.74159   -11.766  116.621
# 15          0.702290  2004  174.60200    -4.022  142.010
# 16          0.693478  1996  184.26730   -10.720   98.623
# 18          0.270776     0  181.15873   -13.991  139.230
# 19          0.706430  1991  265.63873   -10.557  116.282
# 21          0.000000     0  211.06893   -11.706  121.284
# 30          0.215080     0  192.15628    -9.256  161.721
# 31          0.627363  1996  235.65016   -13.277  111.834
# 32          0.415050  1987  335.33342    -5.763   76.096
# 33          0.000000     0  162.06322   -12.370  110.167
# 34          0.549342  2003  216.92036    -8.238  123.943
# 35          0.000000     0   44.19873   -17.472   79.050
# 38          0.292097     0  318.45832   -11.580   71.533
# 40          0.000000  1994  146.15465   -12.158  137.567
# 43          0.450762  1990  267.59791   -13.306   73.507
# 44          0.285176     0  196.17914   -12.493  116.903
# 46          0.270776  1988  101.74649    -6.905   96.686
# 47          0.250420     0  207.41179   -18.340   40.270
# 48          0.000000     0  161.95873   -11.680  104.790
# 49          0.590860  2003  180.03546    -8.537  158.404
# 50          0.000000     0  248.99873   -13.795  129.034
# 51          0.619306     0  188.49914    -7.659  170.079
# 53          0.911733  2002  367.01995    -5.278   88.570
# 56          0.372530  2008  226.40281    -5.627  154.585
# ..               ...   ...        ...       ...      ...
# 170         0.650767  1994  382.01424    -7.971  137.589
# 181         0.635906  2006  345.75628   -18.942  122.002
# 182         0.587427  1993  188.31628    -9.958  115.906
# 183         0.304170  1984  206.78485    -7.651  152.910
# 184         0.595479  1991  255.65995   -10.672  103.976
# 186         0.528782     0  102.45179   -21.343   87.279
# 187         0.735456     0  241.84118    -7.950  105.294
# 188         0.518310  1985  259.97016   -14.283   99.948
# 189         0.730950  1989  329.69098    -6.658  115.106
# 193         0.000000  1994  157.93587   -11.051  121.852
# 194         0.545937  2009  204.06812   -13.708  111.629
# 195         0.296078     0  194.82077   -12.098   42.797
# 196         0.457447  1990  174.23628    -9.790  206.941
# 197         0.274459     0  290.06322   -14.492  152.606
# 200         0.379523     0  289.64526    -6.460  137.746
# 201         0.265861     0  134.68689   -11.197  106.218
# 203         0.261733     0  184.68526    -9.579  104.520
# 204         0.382935     0  290.95138   -15.456  109.857
# 206         0.823479  1985  285.98812   -11.341  136.320
# 207         0.771163  2006  232.28036   -15.606  117.495
# 210         0.639792  2001  289.38404    -3.573  117.362
# 211         0.247248     0  287.94730    -8.212  132.106
# 212         0.590891  2006  217.57342   -10.786  186.440
# 215         0.407233  1993  202.05669   -10.319   70.759
# 216         0.000000     0  183.17016   -14.668  180.521
# 219         0.566227  1979  241.86730   -12.328   94.423
# 227         0.773293  1999  269.34812    -2.976  124.915
# 228         0.614006  1993  343.43138    -9.808   94.705
# 233         0.000000     0  140.56444   -11.616  100.869
# 234         0.000000  2006  171.67628    -8.473  208.567
#
#             artist_mbtags                                            release  \
# 0                    none                                    Tales Of Wonder
# 4         soul and reggae                                             Joyful
# 5                    none                                         La Leyenda
# 6               colombian  El Amor En Los Tiempos del Colera (Love In The...
# 7                    none                                      Unforgettable
# 9                    rock                  OK Computer (Collector's Edition)
# 10              seen live                                          Nocturama
# 15         northern irish                                        Final Straw
# 16         jazz and blues  Martin Scorsese Presents The Blues: Stevie Ray...
# 18                   none                                  Israel Homecoming
# 19       alternative rock                              Blood Sugar Sex Magik
# 21                   none       Rewind Selecta: Up Tempo Collection Volume 3
# 30                   none                                 Ghetto-ology + Dub
# 31         jazz and blues                                   Blues At Sunrise
# 32            heavy metal                           A Little South Of Sanity
# 33                   none                    When All God's Singers Get Home
# 34                british  Brother Bear Original Soundtrack (English Vers...
# 35                   none                                        Gift Grub 7
# 38                   none                                   Homecoming Hymns
# 40                   none                                Les Années Chansons
# 43                hip-hop                            Original Album Classics
# 44                   none                The Best Of Homecoming - Volume One
# 46                hip-hop                               Tougher Than Leather
# 47                   none                                       Freedom Band
# 48                   folk                Celebrating 50 Years Of Del McCoury
# 49              seen live                                          Nocturama
# 50                   none               Thank You Mama For Praying For Me...
# 51                   folk                                   Del And The Boys
# 53       alternative rock                                         By The Way
# 56                   none                        Dance Hall Showcase Vol. II
# ..                    ...                                                ...
# 170             seen live                                        Let Love In
# 181             seen live                                 The Boatmans Call
# 182                  rock                  Pablo Honey (Collector's Edition)
# 183                  none  George Phang: Power House Selector's Choice Vo...
# 184           heavy metal                        Pandora's Box (Display Box)
# 186                  rock                     The Bends (Collectors Edition)
# 187      alternative rock                                   Stadium Arcadium
# 188               hip-hop                                       King Of Rock
# 189           heavy metal                                           Big Ones
# 193                  none                                Les Années Chansons
# 194                  rock                  Pablo Honey (Collector's Edition)
# 195                  none                          Southern Convention Songs
# 196               british                              Serious Hits... Live!
# 197                  none                               Jerusalem Homecoming
# 200  classic pop and rock                                              SWALK
# 201                  folk                                         The Family
# 203                  none                                Emergency Broadcast
# 204             seen live              Henry's Dream (2010 Digital Remaster)
# 206               british                                               Hits
# 207       soul and reggae                                             Joyful
# 210                   pop                                         Invincible
# 211                  none                                            Attack!
# 212        northern irish                                       Chasing Cars
# 215             seen live                                         Live Seeds
# 216                  folk                                         By Request
# 219           heavy metal                                  Night In The Ruts
# 227      alternative rock                                    Californication
# 228               british                                         Both Sides
# 233                  none                                         Copacabana
# 234                  folk                                   The Promise Land
#
#      release_7digitalid
# 0                148547
# 4                350343
# 5                756949
# 6                439614
# 7                205255
# 9                405065
# 10               275954
# 15                 2308
# 16               391613
# 18                64629
# 19                30962
# 21               444849
# 30               225997
# 31               405525
# 32               419069
# 33               550682
# 34               653590
# 35                49859
# 38               143822
# 40                34757
# 43               597033
# 44               155742
# 46               307454
# 47               116383
# 48               758081
# 49               275954
# 50               600571
# 51               757780
# 53                 9153
# 56               203410
# ..                  ...
# 170                8423
# 181                1280
# 182              404997
# 183              420159
# 184              290095
# 186              405019
# 187               32950
# 188              296948
# 189               14327
# 193               34757
# 194              404997
# 195              155721
# 196               41136
# 197               64628
# 200              248564
# 201              757779
# 203              484159
# 204              776437
# 206               40839
# 207               68828
# 210              289547
# 211              148550
# 212              358348
# 215               10148
# 216              758079
# 219              289322
# 227                9152
# 228               40838
# 233              291956
# 234              757775
#
# [113 rows x 16 columns]

# %%
#notice that some songs have year or hotttnesss of 0 or artist_mbtags of 'none'
#these are missing data that aren't labeled as such

#we want to remove these cases but dataframes use different syntax than lists
#the model we need is: df=df[df[var]!=val]
#read that expression dataframe = df WHERE variable is NOT equal to value

#let's try it for one variable
artist_data = artist_data[artist_data['artist_mbtags']!='none']
artist_data.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  artist_familiarity  artist_hotttnesss  \
# count    71.000000     71.000000           71.000000          71.000000
# mean   5044.647887   5044.647887            0.733710           0.550294
# std    2798.760012   2798.760012            0.116717           0.124893
# min     406.000000    406.000000            0.522590           0.360446
# 25%    2816.000000   2816.000000            0.655921           0.479408
# 50%    4880.000000   4880.000000            0.694022           0.578302
# 75%    7755.500000   7755.500000            0.833968           0.610731
# max    9805.000000   9805.000000            0.899935           0.808502
#
#        song_hotttnesss         year    duration   loudness       tempo  \
# count        71.000000    71.000000   71.000000  71.000000   71.000000
# mean          0.531858  1574.563380  235.562225 -10.038423  126.522380
# std           0.217939   820.747059   60.547862   3.989392   32.845556
# min           0.000000     0.000000  101.746490 -21.343000   64.101000
# 25%           0.444373  1981.500000  188.747300 -11.976000  103.076000
# 50%           0.579938  1993.000000  235.650160  -9.959000  117.495000
# 75%           0.694399  2002.500000  273.018325  -6.981000  146.251000
# max           0.945995  2009.000000  382.014240  -2.267000  208.567000
#
#        release_7digitalid
# count           71.000000
# mean        306990.394366
# std         271612.405781
# min            738.000000
# 25%          31436.000000
# 50%         289322.000000
# 75%         484234.000000
# max         776437.000000

# %%
#now practice using a for loop to correct multiple variables
vars = ['year','song_hotttnesss']
for var in vars:
    artist_data = artist_data[artist_data[var]!=0]
    
artist_data.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  artist_familiarity  artist_hotttnesss  \
# count    52.000000     52.000000           52.000000          52.000000
# mean   4884.076923   4884.076923            0.767617           0.602199
# std    2802.668797   2802.668797            0.101267           0.091460
# min     507.000000    507.000000            0.522590           0.360446
# 25%    2472.500000   2472.500000            0.681581           0.576904
# 50%    4472.500000   4472.500000            0.818319           0.605649
# 75%    7578.000000   7578.000000            0.866520           0.667295
# max    9477.000000   9477.000000            0.899935           0.808502
#
#        song_hotttnesss         year    duration   loudness       tempo  \
# count        52.000000    52.000000   52.000000  52.000000   52.000000
# mean          0.614467  1995.576923  247.691603  -9.777173  119.652058
# std           0.134670     8.139341   59.680690   4.150204   30.112303
# min           0.270776  1979.000000  101.746490 -19.976000   64.101000
# 25%           0.518310  1990.000000  204.166078 -12.287500   99.881000
# 50%           0.607256  1995.000000  244.244445  -9.958500  115.506000
# 75%           0.701712  2003.000000  283.833017  -6.630500  136.637250
# max           0.945995  2009.000000  382.014240  -2.267000  206.941000
#
#        release_7digitalid
# count           52.000000
# mean        213529.538462
# std         210107.413809
# min            738.000000
# 25%          15222.500000
# 50%         217467.000000
# 75%         394959.000000
# max         653590.000000

# %%
#we now have the 52 complete cases out of 237 original cases

# %% [markdown]
# ## Exploratory Data Visualization
#
# Getting to know your data is an important step. So far, we've seen how to drop missing data and find basic descriptive statistics, but visualization can help you get a better sense of your data and find outliers (unusual cases) that require further examination.
#
# In this section we'll use matplotlib to create some basic visualizations, including histograms, scatter plots and line plots. Matplotlib is very flexible and allows combining or paneling multiple plots as well as specifying custom style features. Because of this flexibility, showing a plot is a separate step from creating it.

# %%
#import matplotlib plus add a shortcut for the primary subset of functions
import matplotlib
import matplotlib.pyplot as plt

#plotting in Jupyter requires a little extra code to display
# %matplotlib inline

# %%
#histograms are great to explore single variables and check for outliers
#let's look at the distribution of songs by year released
indata['year'].hist()

# %%
#That really doesn't tell us much
#Maybe we need to go back and deal with those zero values for year
plot_data = indata[indata['year']!=0]

#now replot and notice how much more we can see without missing data/outliers
plot_data['year'].hist()

# %%
#we can now see that the dataset is not evenly spread across decades
#it's not clear whether this reflects all songs released or the data's coverage
#but we should be aware when planning other procedures

# %%
#you can also panel a histogram by another variable
#let's get a quick idea of how different artist's songs are spread out
plot_data['year'].hist(by=plot_data['artist_name'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025266D20048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266DAA4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266DD0A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266DF9FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025266E29588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266E52B00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266E830B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266EAC668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025266EAC6A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266F06160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266F2C6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266F53C50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000025266F86208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266FAD780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000025266FD6CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000252670062B0>]],
#       dtype=object)

# %% [markdown]
# We can see that our artists vary widely. Some, like Ayo and Del McCoury Band only have songs from one year in the data. others, like Radiohead and Michael Jackson have releases from across multiple decades.
#
# There are parameters that can be adjusted to improve the display and prevent overlap, but for now, we'll move on to scatterplots, a different way to inspect the relationship between two variables.
#
# Histograms are best suited to numeric variables with many different values, and can be paneled by a categorical variable. Scatterplots work best for 2 numeric variables with many values.

# %%
#Has music gotten louder over the years?
#We can use a scatterplot to check
plt.scatter(plot_data['year'],plot_data['loudness'])
plt.show()

# %%
#the x-axis is years
#the y-axis is loudness

#at a glance, they look fairly unconnected; we can test later
#what would happen with the missing data/outliers still in?
plt.scatter(indata['year'],indata['loudness'])
plt.show()

# %%
#two variables likely to be related are familiarity and hotttness
plt.scatter(plot_data['artist_hotttnesss'],plot_data['artist_familiarity'])
plt.show()

# %%
#check out more options like paneling and colors/shapes later
#https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html

#one bonus example: xkcd style with markers sized by number of songs by artist
with plt.xkcd():
    plt.scatter(plot_data['artist_hotttnesss'],plot_data['artist_familiarity'],plot_data.groupby('artist_name').count()**2)

# %% [markdown]
# Another useful types of plot is boxplots. Boxplots summarize mean and outliers for one or more variables.

# %%
#plot duration
#the horizontal line in the center of the box is the median
#the top/bottom of the box are the quartiles
#any points beyond the whiskers are outliers that are unusually high or low
plt.boxplot(plot_data['duration'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25268486f28>,
#   <matplotlib.lines.Line2D at 0x252684912b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x252684915f8>,
#   <matplotlib.lines.Line2D at 0x25268491940>],
#  'boxes': [<matplotlib.lines.Line2D at 0x25268486ac8>],
#  'medians': [<matplotlib.lines.Line2D at 0x25268491c88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25268491fd0>],
#  'means': []}

# %%
#Typical song durations are between 200 and 300 seconds (3.3 to 5 minutes)
#some last close to 10 minutes

# %%
#plot duration, loudness and tempo on the same boxplot
data = [plot_data['loudness'],plot_data['tempo'],plot_data['duration']]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x252684e94e0>,
#   <matplotlib.lines.Line2D at 0x252684e9828>,
#   <matplotlib.lines.Line2D at 0x252684f5c18>,
#   <matplotlib.lines.Line2D at 0x252684f5f60>,
#   <matplotlib.lines.Line2D at 0x25268509390>,
#   <matplotlib.lines.Line2D at 0x252685096d8>],
#  'caps': [<matplotlib.lines.Line2D at 0x252684e9b70>,
#   <matplotlib.lines.Line2D at 0x252684e9eb8>,
#   <matplotlib.lines.Line2D at 0x252684fe2e8>,
#   <matplotlib.lines.Line2D at 0x252684fe630>,
#   <matplotlib.lines.Line2D at 0x25268509a20>,
#   <matplotlib.lines.Line2D at 0x25268509d68>],
#  'boxes': [<matplotlib.lines.Line2D at 0x252684e90f0>,
#   <matplotlib.lines.Line2D at 0x252684f58d0>,
#   <matplotlib.lines.Line2D at 0x252684fed68>],
#  'medians': [<matplotlib.lines.Line2D at 0x252684e9f98>,
#   <matplotlib.lines.Line2D at 0x252684fe978>,
#   <matplotlib.lines.Line2D at 0x25268509e48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x252684f5588>,
#   <matplotlib.lines.Line2D at 0x252684fecc0>,
#   <matplotlib.lines.Line2D at 0x25268514438>],
#  'means': []}

# %%
#scaling is an issue for plots with multiple variables
#here, the range on duration is so wide that it's hard to see loudness
#you can rescale or normalize but it makes the individual boxes less useful
data = [plot_data['loudness'],plot_data['tempo']/10,plot_data['duration']/20]
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25268563898>,
#   <matplotlib.lines.Line2D at 0x25268563be0>,
#   <matplotlib.lines.Line2D at 0x2526856efd0>,
#   <matplotlib.lines.Line2D at 0x25268579358>,
#   <matplotlib.lines.Line2D at 0x25268583748>,
#   <matplotlib.lines.Line2D at 0x25268583a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x25268563f28>,
#   <matplotlib.lines.Line2D at 0x2526856e2b0>,
#   <matplotlib.lines.Line2D at 0x252685796a0>,
#   <matplotlib.lines.Line2D at 0x252685799e8>,
#   <matplotlib.lines.Line2D at 0x25268583dd8>,
#   <matplotlib.lines.Line2D at 0x25268583eb8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x252685634a8>,
#   <matplotlib.lines.Line2D at 0x2526856ec88>,
#   <matplotlib.lines.Line2D at 0x25268583400>],
#  'medians': [<matplotlib.lines.Line2D at 0x2526856e5f8>,
#   <matplotlib.lines.Line2D at 0x25268579d30>,
#   <matplotlib.lines.Line2D at 0x2526858c4a8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2526856e940>,
#   <matplotlib.lines.Line2D at 0x25268579e10>,
#   <matplotlib.lines.Line2D at 0x2526858c7f0>],
#  'means': []}

# %% [markdown]
# ## Basic statistics and analysis
#
# The final section of the workshop demonstrates how to perform a few basic statistics (T-tests, correlation, and Chi-square tests) using dataframes. Pandas includes some statistical tools, but we will draw on a number of other packages to get the most complete results for each procedure.
#
# The explanations for statistics here will be quite brief. If you are considering using a statistical procedure in your own research, we recommend you consult a statistics or methods text in your own discipline, a free peer-reviewed [open textbook](https://guides.lib.vt.edu/oer/opentextbooks), or [SAIG](https://saig.stat.vt.edu) (VT's statistical consulting group).

# %% [markdown]
# ### T-tests (difference in means)

# %%
#lets go back to the original data and compare loudness between two artists
#loudness had no missing data, so we don't need to remove any cases

#count the number of songs by each artist
indata['artist_name'].count()
# Out:
# 237

# %%
#oops - we need a way to summarize the number of songs (rows) by artist name
indata.artist_name.value_counts()
# Out:
# Mario Rosenstock                         13
# Aerosmith                                12
# The Jackson Southernaires                12
# Sugar Minott                             12
# Phil Collins                             12
# Line Renaud                              11
# Radiohead                                11
# Nick Cave & The Bad Seeds                11
# Mikey Dread                              11
# Snow Patrol                              11
# Bill & Gloria Gaither                    11
# Red Hot Chili Peppers                    10
# Pumpkin Buzzard                          10
# Selena                                   10
# The Del McCoury Band                     10
# Stevie Ray Vaughan And Double Trouble    10
# Ayo                                      10
# Shakira                                  10
# White Heart                              10
# Jacques Douai                            10
# Michael Jackson                          10
# RUN-DMC                                  10
# Name: artist_name, dtype: int64

# %%
#find the mean loudness of RUN-DMC (hip-hop) and Bill and Gloria Gaither (Gospel)
#remember loudness had no missing data so we can use it as-is

#first create subsets to compare
#notice that == is used for comparison
#one = always means assignment; two mean compare
gaither = indata[indata['artist_name']=='Bill & Gloria Gaither']
run = indata[indata['artist_name']=='RUN-DMC']
print('gaither mean:',gaither['loudness'].mean())
print('run-dmc mean:',run['loudness'].mean())
# Out:
# gaither mean: -13.38881818181818
# run-dmc mean: -9.5013

# %%
#at least in the sample, my hypothesis appears to be correct; the mean loudness for run is higher
#let's see if we have the statistical power to draw a conclusion
#Test the difference of means using a T-test from statsmodels
import statsmodels.stats.weightstats as stats
stats.ttest_ind(gaither['loudness'],run['loudness'])
# Out:
# (-2.6179667186158575, 0.016923139260728696, 19.0)

# %% [markdown]
# To interpret the above:
#
# - The first value is the T-Statistic, which is used to conduct the test. Larger values are associated with more probability of a meaningful difference
# - The **second value, the p-value of the test**, is the key here. If p is less than a given value (usually 0.05), there is a statistically significant difference between the groups; e.g. they're not random samples drawn from the same population. Remember there is still a 1 in 20 probability that you're wrong, but if the test value p is decreased, we then increase the probability of not finding a difference even when there is a true difference.
# - The third value is the degrees of freedom for the test, which is based on the number of cases. More cases provide more degrees of freedom, which allows for more statistical confidence even with the same differences in means. This is why you can't just ask the three people next to you which band is better and assume that more people in the US (or even the class) prefer whichever two of the three of them say.
#
# So we might summarize:
# > *The mean loudness of Bill and Gloria Gaither's songs is significantly lower than RUN-DMC's (p<0.017).*

# %% [markdown]
# ### Chi-square tests (relationship between categorical variables)

# %% [markdown]
# But what if want to know about the relationship between categorical variables? A T-test compares values on a numeric variable between categories. A Chi-square test is more appropriate for 2 categorical variables.
#
# Here's one situation you might use a Chi-square:
# > Some musical genres seem to be more enduring than others. Rock, Adult Contemporary, Country and Gospel/Christian are a few examples of genre labels that continue to be salient over many years, even if the style itself changes throughout that time. Choose 3 common genres to test whether songs (in the subset) are released with the same relative frequency across the 1980s, 1990s and 2000s between the three genres.

# %%
#we'll use data here not limited to multi-song artists
indata2 = pd.read_csv('http://bit.ly/msd_genres')
indata2.head()
# Out:
#    Unnamed: 0             song_id           artist_id  \
# 0           1  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3
# 1           3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C
# 2          14  SOBONFF12A6D4F84D8  ARIK43K1187B9AE54C
# 3          23  SOBBUGU12A8C13E95D  ARMAC4T1187FB3FA4C
# 4          30  SOGNCJP12A58A80271  ARB29H41187B98F0EF
#
#                  artist_name  artist_familiarity  artist_hotttnesss  \
# 0               The Box Tops            0.630630           0.417500
# 1                   Adam Ant            0.630382           0.454231
# 2              Lionel Richie            0.776676           0.553072
# 3  The Dillinger Escape Plan            0.839963           0.541889
# 4              Terry Callier            0.706828           0.416173
#
#                              title  song_hotttnesss  year   duration  \
# 0                        Soul Deep              NaN  1969  148.03546
# 1                  Something Girls              NaN  1982  233.40363
# 2          Tonight Will Be Alright              NaN  1986  307.38240
# 3  Setting Fire to Sleeping Giants         0.666528  2004  207.77751
# 4     Do You Finally Need A Friend         0.413740  1972  342.56934
#
#    loudness    tempo         artist_mbtags                 release  \
# 0    -9.843  121.274  classic pop and rock              Dimensions
# 1    -9.013  119.293                    uk           Friend Or Foe
# 2    -8.346  125.197       soul and reggae  Dancing On The Ceiling
# 3    -4.264  166.862        rock and indie            Miss Machine
# 4   -11.939  110.189  classic pop and rock         Occasional Rain
#
#    release_7digitalid
# 0              300822
# 1              287650
# 2               25811
# 3              223365
# 4              228326

# %%
#find out how many total cases you have using len (for length)
len(indata2)
# Out:
# 1988

# %%
#use a histogram to see how many songs you have over the years
indata2['year'].hist()

# %%
#time to clean up the data
g_data = indata2[indata2['year']!=0]
g_data['year'].hist()

# %%
#We have the most data from the 2000s
#But still quite a bit from the 80s and 90s

#create a decades variable
#function for each row to create a (string) decade variable
def makedecade(row):
    if 1980<=row['year']<1990:
        val='80s'
    elif 1990<=row['year']<2000:
        val='90s'
    elif 2000<=row['year']<2010:
        val='00s'
    else:
        val=''
    return val

#apply does the same thing to each column (axis=0) or row (axis=1) in the dataframe
#apply makedecade to each row to create a new column with decades
g_data['decade'] = g_data.apply(makedecade,axis=1)
g_data.head()
# Out:
# C:\Users\ndporter\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Unnamed: 0             song_id           artist_id  \
# 0           1  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3
# 1           3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C
# 2          14  SOBONFF12A6D4F84D8  ARIK43K1187B9AE54C
# 3          23  SOBBUGU12A8C13E95D  ARMAC4T1187FB3FA4C
# 4          30  SOGNCJP12A58A80271  ARB29H41187B98F0EF
#
#                  artist_name  artist_familiarity  artist_hotttnesss  \
# 0               The Box Tops            0.630630           0.417500
# 1                   Adam Ant            0.630382           0.454231
# 2              Lionel Richie            0.776676           0.553072
# 3  The Dillinger Escape Plan            0.839963           0.541889
# 4              Terry Callier            0.706828           0.416173
#
#                              title  song_hotttnesss  year   duration  \
# 0                        Soul Deep              NaN  1969  148.03546
# 1                  Something Girls              NaN  1982  233.40363
# 2          Tonight Will Be Alright              NaN  1986  307.38240
# 3  Setting Fire to Sleeping Giants         0.666528  2004  207.77751
# 4     Do You Finally Need A Friend         0.413740  1972  342.56934
#
#    loudness    tempo         artist_mbtags                 release  \
# 0    -9.843  121.274  classic pop and rock              Dimensions
# 1    -9.013  119.293                    uk           Friend Or Foe
# 2    -8.346  125.197       soul and reggae  Dancing On The Ceiling
# 3    -4.264  166.862        rock and indie            Miss Machine
# 4   -11.939  110.189  classic pop and rock         Occasional Rain
#
#    release_7digitalid decade
# 0              300822
# 1              287650    80s
# 2               25811    80s
# 3              223365    00s
# 4              228326

# %%
#the warning above is not an error
#it's pandas telling you to be careful changing copies
#our data still turned out how we wanted


#remove decades outside the period of interest (and data missing on year)
g_data = g_data[g_data['decade']!='']
g_data.head()
# Out:
#    Unnamed: 0             song_id           artist_id  \
# 1           3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C
# 2          14  SOBONFF12A6D4F84D8  ARIK43K1187B9AE54C
# 3          23  SOBBUGU12A8C13E95D  ARMAC4T1187FB3FA4C
# 7          46  SOTSEJY12AB0180F56  ART3O5Z1187B9AB043
# 8          47  SOTSETT12AB01863B8  AR5U94U1187FB5CDCF
#
#                  artist_name  artist_familiarity  artist_hotttnesss  \
# 1                   Adam Ant            0.630382           0.454231
# 2              Lionel Richie            0.776676           0.553072
# 3  The Dillinger Escape Plan            0.839963           0.541889
# 7         Stevie Ray Vaughan            0.733799           0.544258
# 8               John Hammond            0.590693           0.452818
#
#                              title  song_hotttnesss  year   duration  \
# 1                  Something Girls              NaN  1982  233.40363
# 2          Tonight Will Be Alright              NaN  1986  307.38240
# 3  Setting Fire to Sleeping Giants         0.666528  2004  207.77751
# 7                        Crossfire              NaN  1992  248.78975
# 8             I Can't Be Satisfied              NaN  2002  195.31710
#
#    loudness    tempo    artist_mbtags                 release  \
# 1    -9.013  119.293               uk           Friend Or Foe
# 2    -8.346  125.197  soul and reggae  Dancing On The Ceiling
# 3    -4.264  166.862   rock and indie            Miss Machine
# 7    -7.805  116.721   jazz and blues           Greatest Hits
# 8   -10.700  123.142             folk                Bluesman
#
#    release_7digitalid decade
# 1              287650    80s
# 2               25811    80s
# 3              223365    00s
# 7              417945    90s
# 8              575531    00s

# %%
#View a list of genres to choose from
g_data.artist_mbtags.value_counts()
# Out:
# rock and indie                124
# classic pop and rock          123
# hip hop rnb and dance hall    121
# uk                            106
# american                       93
# british                        82
# pop and chart                  64
# folk                           57
# rock                           54
# german                         52
# finnish                        50
# country                        45
# punk                           44
# soul and reggae                43
# alternative rock               42
# french                         39
# jazz and blues                 36
# production music               22
# Name: artist_mbtags, dtype: int64

# %% [markdown]
# Investigate the following hypothesis using Chi-square:
# > The number of songs released in the genres "folk", "rock" and "soul and reggae" were distributed differently across the decades of the 80s, 90s and 2000s. Of the three, soul and reggae is likely to be more closely tied to individual time periods and less consistent across the decades.

# %%
#Restrict to key genres

#list genres
genres = ['folk','rock','soul and reggae']

#loop over rows with list and mark if genre matches
def genreIndicator(row):
    temp = 0
    for genre in genres:
        if row['artist_mbtags']==genre:
            temp += 1
    return temp

#create new variable using function
g_data['keep']=g_data.apply(genreIndicator,axis=1)

#remove other genres and inspect data
g_data = g_data[g_data['keep'] != 0]
g_data.head()
# Out:
#     Unnamed: 0             song_id           artist_id    artist_name  \
# 2           14  SOBONFF12A6D4F84D8  ARIK43K1187B9AE54C  Lionel Richie
# 8           47  SOTSETT12AB01863B8  AR5U94U1187FB5CDCF   John Hammond
# 11          55  SODHVES12A6701CE6B  AR3793X1187FB50CB3      Chris Rea
# 21          94  SORWHWY12A6702038E  ARXWAQQ1187B9AE954         Redman
# 29         115  SOFRAZJ12A8C143CDB  ARR9XGB1187B9912E6    Boyz II Men
#
#     artist_familiarity  artist_hotttnesss                       title  \
# 2             0.776676           0.553072     Tonight Will Be Alright
# 8             0.590693           0.452818        I Can't Be Satisfied
# 11            0.643183           0.500691  Driving Home For Christmas
# 21            0.743130           0.493567                 WKYA (drop)
# 29            0.790923           0.601185              On Bended Knee
#
#     song_hotttnesss  year   duration  loudness    tempo    artist_mbtags  \
# 2               NaN  1986  307.38240    -8.346  125.197  soul and reggae
# 8               NaN  2002  195.31710   -10.700  123.142             folk
# 11         0.767728  1986  241.16200    -8.531  180.149             rock
# 21         0.570106  2001  124.18567   -10.296   85.008  soul and reggae
# 29         0.345802  1994  329.27302    -7.103  116.473  soul and reggae
#
#                     release  release_7digitalid decade  keep
# 2    Dancing On The Ceiling               25811    80s     1
# 8                  Bluesman              575531    00s     1
# 11  The Road To Hell Part 2               17220    80s     1
# 21              Malpractice                8552    00s     1
# 29                   Legacy              523481    90s     1

# %%
#a crosstab table shows how many rows have each combination of values for 2 variables

#run a crosstab table of genre and decade
tab = pd.crosstab(g_data['decade'],g_data['artist_mbtags'])
tab
#it looks like soul and reggae may be different (relatively more common in 2000s than before)
# Out:
# artist_mbtags  folk  rock  soul and reggae
# decade
# 00s              31    33               32
# 80s               7     6                3
# 90s              19    15                8

# %%
#Chi-square helps to determine if there is a relationship...
#by comparing cell counts to those expected randomly 

#test hypothesis
#notice you can import a single procedure from a package
from scipy.stats.contingency import chi2_contingency
chi2_contingency(tab)
# Out:
# (4.26062066503468,
#  0.37188218379120147,
#  4,
#  array([[35.53246753, 33.66233766, 26.80519481],
#         [ 5.92207792,  5.61038961,  4.46753247],
#         [15.54545455, 14.72727273, 11.72727273]]))

# %% [markdown]
# To interpret the above:
#
# - The first value is the Chi-squared statistic, which is used to conduct the test. Larger values are associated with more probability of a meaningful difference
# - The **second value, the p-value of the test**, is the key here. If p is less than a given value (usually 0.05), there is a statistically significant relationship between the variables; e.g. one is not randomly distributed across the other. Remember there is still a 1 in 20 probability that you're wrong, but if the test value p is decreased, we then increase the probability of not finding a relationship even when there is a true relationship.
# - The third value is the degrees of freedom for the test.
# - The fourth result is the array of expected values. This assumes each variable is randomly distributed across the other
#
# So we might summarize, using a p<0.05 criterion:
# > *With p<0.37, we do not find evidence of a statistical difference in the distribution of number of folk, rock and soul & reggae music across the 80s, 90s and 2000s.*
#
# The non-finding does not mean we assume there is no relationship. If we had a larger sample, it's quite likely we would find a relationship. Additionally, our data may not be of equal quality or completeness for each decade.

# %% [markdown]
# ### Correlation (relationship between interval variables)

# %% [markdown]
# When you have two interval-level (fully numeric) variables to compare, you can use correlation to test whether if one is higher, the other tends to be higher (positive), lower (negative) or unrelated (zero/non-significant).
#
# Here is the task for this section:
# > There has been some speculation that the hotttnesss and familiarity measurement in the Million Song data might be biased toward music that was newer when the data were collected (2010). Investigate the relationship between year (not recoded) and the three variables to test whether there is reason to further investigate the potential for such bias.

# %%
#read in full subset of Million song data
indata3 = pd.read_csv('http://bit.ly/msd_subset_all')

#check it out
len(indata3)
# Out:
# 10000

# %%
indata3.head()
# Out:
#    Unnamed: 0             song_id           artist_id       artist_name  \
# 0           0  SOMZWCG12A8C13C480  ARD7TVE1187B99BFB1            Casual
# 1           1  SOCIWDW12A8C13D406  ARMJAGH1187FB546F3      The Box Tops
# 2           2  SOXVLOJ12AB0189215  ARKRRTF1187B9984DA  Sonora Santanera
# 3           3  SONHOTT12A8C13493C  AR7G5I41187FB4CE6C          Adam Ant
# 4           4  SOFSOCN12A8C143F5D  ARXR32B1187FB57099               Gob
#
#    artist_familiarity  artist_hotttnesss             title  song_hotttnesss  \
# 0            0.581794           0.401998  I Didn't Mean To         0.602120
# 1            0.630630           0.417500         Soul Deep              NaN
# 2            0.487357           0.343428   Amor De Cabaret              NaN
# 3            0.630382           0.454231   Something Girls              NaN
# 4            0.651046           0.401724    Face the Ashes         0.604501
#
#    year   duration  loudness    tempo         artist_mbtags  \
# 0     0  218.93179   -11.197   92.198                  none
# 1  1969  148.03546    -9.843  121.274  classic pop and rock
# 2     0  177.47546    -9.689  100.070                  none
# 3  1982  233.40363    -9.013  119.293                    uk
# 4  2007  209.60608    -4.501  129.738                  none
#
#                                release  release_7digitalid
# 0                          Fear Itself              300848
# 1                           Dimensions              300822
# 2  Las Numero 1 De La Sonora Santanera              514953
# 3                        Friend Or Foe              287650
# 4                        Muertos Vivos              611336

# %%
#remove missing data on all variables
vars = ['year','song_hotttnesss','artist_hotttnesss','artist_familiarity']
indata3 = indata3.dropna(subset=vars) #defined NaN
for var in vars:
    indata3 = indata3[indata3[var]!=0] #missing set to zero
indata3 = indata3[vars] #drop exra variables
indata3.head()
# Out:
#     year  song_hotttnesss  artist_hotttnesss  artist_familiarity
# 4   2007         0.604501           0.401724            0.651046
# 8   1984         0.265861           0.332276            0.426668
# 15  1987         0.405116           0.447935            0.636424
# 18  2004         0.684136           0.513463            0.707200
# 23  2004         0.666528           0.541889            0.839963

# %%
#Use pandas to get correlation matrix for all variables
#correlations are pairwise (between 2 variables)
#they range from -1 to 1, with zero being random/unrelated
corrMatr = indata3.corr()
corrMatr
# Out:
#                         year  song_hotttnesss  artist_hotttnesss  \
# year                1.000000         0.065018           0.071455
# song_hotttnesss     0.065018         1.000000           0.459118
# artist_hotttnesss   0.071455         0.459118           1.000000
# artist_familiarity  0.102442         0.499423           0.782037
#
#                     artist_familiarity
# year                          0.102442
# song_hotttnesss               0.499423
# artist_hotttnesss             0.782037
# artist_familiarity            1.000000

# %%
#each variable is perfectly correlated with itself
#other correlations range from 0.07(minimal) to 0.78 (very high)

#we're interested only in the first column (correlation with year)

#use scipy to get p-value for hypothesis testing
import scipy.stats
scipy.stats.pearsonr(indata3['year'], indata3['song_hotttnesss'])
# Out:
# (0.06501756123228783, 0.0007270482408098302)

# %% [markdown]
# The results can be interpreted:
# - the first number returned is the correlation (the same as in corr() above)
# - the second number is the statistical significance (p-value)
# - remember that the e-NUM notation is scientific and means move the decimal to the left NUM positions
#
# We find here:
# > There is a small but significant (p<.0007) positive correlation between year and song hotttnesss. Songs released in later years tend to be rated somewhat more hot than earlier songs.

# %%
#we can also view this on a scatter-plot
plt.scatter(indata3['year'], indata3['song_hotttnesss'])
plt.show()

# %%
#the correlation is small enough, it's hard to tell visually
#for comparison, here is a strong correlation
plt.scatter(indata3['artist_hotttnesss'], indata3['artist_familiarity'])
plt.show()

# %% [markdown]
# Thanks for participating in this workshop. We hope it's been helpful! Feel free to save, share and adapt the notebook from [this repository](https://github.com/ndporter/pandasS19).
#
# If you would like further assistance with pandas or other data questions, please contact [dataservices@vt.edu](mailto:dataservices@vt.edu).
